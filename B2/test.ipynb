# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)
df.head() # in 5 phần tử đầu tiên
df.tail(1) # in 1 dòng cuối cùng
df["Age"] #Truy cập 1 series
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# series = list
bank_accounts = pd.Series([2514,45830,100000,0,5000,300], name="Bank Accounts")
bank_accounts.describe() # Thống kê cơ bản
# Out:
# count         6.000000
# mean      25607.333333
# std       40490.458069
# min           0.000000
# 25%         853.500000
# 50%        3757.000000
# 75%       35622.500000
# max      100000.000000
# Name: Bank Accounts, dtype: float64

# %%
# đọc file csv
screentime_data = pd.read_csv("screentime.csv")
screentime_data.head(10)
# Out:
#   user_id  age            gender     occupation  work_mode  screen_time_hours  \
# 0   U0001   33            Female       Employed     Remote              10.79
# 1   U0002   28            Female       Employed  In-person               7.40
# 2   U0003   35            Female       Employed     Hybrid               9.78
# 3   U0004   42              Male       Employed     Hybrid              11.13
# 4   U0005   28              Male        Student     Remote              13.22
# 5   U0006   28  Non-binary/Other  Self-employed     Hybrid               9.83
# 6   U0007   42  Non-binary/Other        Retired     Remote               6.02
# 7   U0008   36              Male       Employed  In-person               6.21
# 8   U0009   26              Male        Student  In-person               6.28
# 9   U0010   34              Male       Employed     Hybrid               9.37
#
#    work_screen_hours  leisure_screen_hours  sleep_hours  sleep_quality_1_5  \
# ...

# %% [markdown]
# - 3 câu hỏi thống kê dữ liệu định lượng
# + Lượng thời gian ngủ của từng nhân viên?
# + Lượng thời gian nhân viên phải làm việc của nhân viên (bao gồm work_screen và leisure_screen)?
# + Lượng thời gian mà nhân viên dành thời gian cho đời sống xã hôi là bao nhiêu tiếng?
# - 3 câu hỏi thống kê dữ liệu định tính:
# + Mức độ stress khi làm việc (scale 0-10)
# + Mức độ sức khoẻ  tin thần (mental_wellness_index_) của nhân viên
# + Hiệu suất làm việc của nhân viên là bao nhiêu phần trăm?

# %%
screentime_data["stress_level_0_10"].describe()
# Out:
# count    400.000000
# mean       8.150500
# std        2.094844
# min        0.000000
# 25%        6.900000
# 50%        8.800000
# 75%       10.000000
# max       10.000000
# Name: stress_level_0_10, dtype: float64
