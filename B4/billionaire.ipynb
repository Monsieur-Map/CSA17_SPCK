# %% [markdown]
# - Dữ liệu bao gồm bao nhiêu hàng + cột? 35 cột + 2640 hàng
# - Kiểu dữ liệu các cột?

# %%
import pandas as pd
df = pd.read_csv("Billionaires Statistics Dataset.csv")
df.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rank                                        2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2575 non-null   float64
#  5   country                                     2602 non-null   object
#  6   city                                        2568 non-null   object
#  7   source                                      2640 non-null   object
#  8   industries                                  2640 non-null   object
#  9   countryOfCitizenship                        2640 non-null   object
# ...

# %% [markdown]
# - Cột gdp_country kiểu dữ liệu gì? -> Có thể thống kê cho kiểu dữ liệu này hay không
# - Cách chuyển dữ liệu cho cột?

# %%
# Trích từ cột gdp_country
gdp_country_series = df["gdp_country"]
gdp_country_series.head()

#gdp_country_series.dtype #dtype('0')
# Out:
# dtype('O')

# %% [markdown]
# # Biến đổi dữ liệu với apply

# %% [markdown]
# > `DataFrame.apply(<Hàm biến đổi>)` thay đổi tất cả giá trị trong cột. Hàm biến đổi có thể là hàm có sẵn hoặc tự định nghĩa.

# %%
# Hàm xử lý dữ liệu "$..,..." -> Number
def process_gdp(gdp_str):
    # Cắt "$"
    gdp_str = gdp_str[1:]
    # Cắt space ("Khoảng trắng") ở sau cùng
    gdp_str = gdp_str.strip()
    # Cắt dấu ","
    gdp_str = gdp_str.replace(",", "")
    # Ép kiểu float
    gdp_float = float(gdp_str)
    return gdp_float
process_gdp("$21,427,700,000,000 ")
# Out:
# 21427700000000.0

# %%
# Apply vào series
gdp_country_series_new = df["gdp_country"].apply(lambda gdp: process_gdp(gdp))
gdp_country_series_new.head()
# to_numberic -> chuyển đổi kiểu dữ liệu từ string -> số
pd.to_numeric(gdp_country_series_new).dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Apply vào series
# ----> 2 gdp_country_series_new = df["gdp_country"].apply(lambda gdp: process_gdp(gdp))
#       3 gdp_country_series_new.head()
#       4 # to_numberic -> chuyển đổi kiểu dữ liệu từ string -> số
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Nhóm dữ liệu (groupby)

# %% [markdown]
# - Phân tích: Những lĩnh vực nào có tổng lượng tài sản lớn nhất?
#   - Nhóm cột finalWorth (tr USD) theo cột industrials /category
#   - Tính tổng cột finalWorth
#   - Sắp xếp theo thứ tự giảm dần

# %%
tong_cate = df[["category", "finalWorth"]].groupby("category").sum()
# DataFrame.sort_values(by=<tên cột>, ascending= True/False)
tong_cate_sorted = tong_cate.sort_values(by = "finalWorth", ascending= True)
tong_cate_sorted.head(10)
# Out:
#                             finalWorth
# category
# Construction & Engineering      118500
# Gambling & Casinos              120500
# Sports                          134500
# Service                         173400
# Telecom                         203500
# Logistics                       239500
# Media & Entertainment           427500
# Metals & Mining                 446800
# Energy                          453500
# Automotive                      525300

# %% [markdown]
# - Phân tích: tính tài sản trung bình của các tỷ phú theo châu lục
