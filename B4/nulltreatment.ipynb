# %%
import pandas as pd
df = pd.read_csv("Billionaires Statistics Dataset.csv")
df.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %% [markdown]
# # Xử lý dữ liệu
# - isnull(), sum()
# - dropan(axis = 1) (xoá tất cả các cột có chữa dữ liệu null)
# - drop(['tên cột'], axis = 1, inplace= True): `bỏ các cột không cần thiết`

# %%
df.isnull().sum()

# %%
df.dropna()

# %%
df =df.dropna(axis=1)

# %%
#Hàm ghi đè dữ liệu cũ
df.drop(["organization"], axis=1, inplace=True)

# %% [markdown]
# # Điền khuyết
# - fillna()
# - bfill: `Thay giá trị khuyết bằng giá trị ngay sao nó`
# - ffill: `Thay giá trị khuyết bằng giá trị ngay trước nó`

# %%
df_filled_0 = df.fillna(0)
df_filled_0.isnull().sum()
df_filled_0.tail()

# %%
#df_billed_0 = df.fillna(method="bfill")
df_billed_0= df.bfill()
df_billed_0.isnull().sum()

# %%
df_filled_0= df.ffill()
df_filled_0.isnull().sum()

# %%
nan_rows_any = df[df.isna().any(axis=1)]
print("\nRows with at least one NaN value:")
print(nan_rows_any)

# %% [markdown]
# # Ép kiểu
# - dtypes() (Nếu là `DataTypes` thì `có "s"` ở sau chữ datatypes còn `Series` thì `không`)
# - Series.astype('<Kiểu dữ liệu>')
# - pd.to_numeric(<cột>): `Để pandas tự chọn kiểu phù hợp`

# %%
df.dtypes

# %%
df_ffill.birthYear = df_ffill.birthYear.astype("int")
df_ffill.birthYear.dtype

# %%
df_ffill.age = pd.to_numeric(df_ffill.age)
df_ffill.age.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df_ffill.age = pd.to_numeric(df_ffill.age)
#       2 df_ffill.age.dtype
#
# NameError: name 'df_ffill' is not defined

# %% [markdown]
# # Dữ liệu trùng lặp
# - df["Têncột"].duplicated().sum()
# - df["Têncột"].drop_duplicates()

# %%
df_dup = df
df_dup.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Xoá cả hàng bị trùng

df_dup = df_dup.drop_duplicates()
df_dup.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_dup[df_dup["rank"].duplicated()]
# Out:
#       rank  finalWorth               category              personName   age  \
# 17      17       59000            Diversified     Julia Koch & family  60.0
# 31      31       38300        Food & Beverage               John Mars  87.0
# 35      35       35000  Finance & Investments             Ken Griffin  54.0
# 41      41       31600       Fashion & Retail       Gerard Wertheimer  72.0
# 43      43       31200              Logistics  Rafaela Aponte-Diamant  78.0
# ...    ...         ...                    ...                     ...   ...
# 2635  2540        1000             Healthcare                 Yu Rong  51.0
# 2636  2540        1000        Food & Beverage  Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate  Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified             Inigo Zobel  66.0
#
# ...

# %%
df_dup.drop_duplicates(subset=["rank"])
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2019  2020        1400            Diversified       Antti Aarnio-Wihuri  83.0
# 2132  2133        1300             Automotive           A. Jayson Adair  53.0
# 2258  2259        1200  Finance & Investments            Sanjay Agarwal  52.0
# 2404  2405        1100       Fashion & Retail      Hari Krishan Agarwal  66.0
# 2539  2540        1000        Food & Beverage       Manohar Lal Agarwal  68.0
#
# ...
